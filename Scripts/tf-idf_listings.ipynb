# %%
import pandas as pd
import sklearn as sk
import math

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import words

train_res = TfidfVectorizer(ngram_range = (1,1), sublinear_tf = True, max_features = 10000).fit_transform(t_reviews["comments_clean"])
