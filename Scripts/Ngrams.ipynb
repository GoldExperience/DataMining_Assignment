# %%
from IPython.display import clear_output
import pandas as pd
import nltk
nltk.download('stopwords')
nltk.download('reuters')
nltk.download('punkt')
clear_output()

# %%
# !pip install textblob
# !python -m textblob.download_corpora
clear_output()

# %%
from textblob import TextBlob

# %%
sentence = "it was trained on movie reviews"
TextBlob(sentence).ngrams(3)
# Out:
# [WordList(['it', 'was', 'trained']),
#  WordList(['was', 'trained', 'on']),
#  WordList(['trained', 'on', 'movie']),
#  WordList(['on', 'movie', 'reviews'])]

# %%
from nltk.corpus import reuters
from nltk import bigrams, trigrams
from collections import Counter, defaultdict
clear_output()

# %%
# Create a placeholder for model
model = defaultdict(lambda: defaultdict(lambda: 0))

# %%
# Count frequency of co-occurance  
for sentence in reuters.sents():
    for w1, w2, w3 in trigrams(sentence, pad_right=True, pad_left=True):
        model[(w1, w2)][w3] += 1

# %%
for w1_w2 in model:
    total_count = float(sum(model[w1_w2].values()))
    for w3 in model[w1_w2]:
        model[w1_w2][w3] /= total_count

# %%
model["Trump","said"]
# Out:
# defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#             {'"': 0.16666666666666666,
#              '.': 0.16666666666666666,
#              'he': 0.5,
#              'the': 0.16666666666666666})

# %%
model["today", "the"]
# Out:
# defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#             {'Bank': 0.05555555555555555,
#              'European': 0.05555555555555555,
#              'Higher': 0.05555555555555555,
#              'Italian': 0.05555555555555555,
#              'Turkish': 0.05555555555555555,
#              'company': 0.16666666666666666,
#              'emirate': 0.05555555555555555,
#              'increase': 0.05555555555555555,
#              'newspaper': 0.05555555555555555,
#              'options': 0.05555555555555555,
#              'overseas': 0.05555555555555555,
#              'pound': 0.05555555555555555,
#              'price': 0.1111111111111111,
#              'public': 0.05555555555555555,
#              'time': 0.05555555555555555})

# %%
model["financial","markets"]
# Out:
# defaultdict(<function __main__.<lambda>.<locals>.<lambda>>,
#             {"'": 0.01639344262295082,
#              '),': 0.01639344262295082,
#              ',': 0.09836065573770492,
#              '.': 0.14754098360655737,
#              '."': 0.01639344262295082,
#              'about': 0.03278688524590164,
#              'also': 0.03278688524590164,
#              'and': 0.06557377049180328,
#              'appear': 0.01639344262295082,
#              'are': 0.06557377049180328,
#              'as': 0.01639344262295082,
#              'but': 0.01639344262295082,
#              'can': 0.01639344262295082,
#              'doing': 0.01639344262295082,
#              'economist': 0.03278688524590164,
#              'expected': 0.03278688524590164,
#              'for': 0.01639344262295082,
#              'give': 0.01639344262295082,
#              'grew': 0.01639344262295082,
#              'had': 0.06557377049180328,
#              'have': 0.04918032786885246,
#              'in': 0.01639344262295082,
#              'might': 0.01639344262295082,
#              'or': 0.01639344262295082,
#              'remain': 0.01639344262295082,
#              'seem': 0.01639344262295082,
#              'should': 0.01639344262295082,
#              'since': 0.01639344262295082,
#              'suddenly': 0.01639344262295082,
#              'that': 0.01639344262295082,
#              'to': 0.01639344262295082,
#              'which': 0.03278688524590164})
