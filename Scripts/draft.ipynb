# %% [markdown]
# # CA683 - Continuous Assignment

# %% [markdown]
# Data from : http://insideairbnb.com/get-the-data.html <br><br>
# Useful link :
# *   https://www.kaggle.com/airbnb/boston + kernel
# *   https://www.kaggle.com/brittabettendorf/berlin-airbnb-data + kernel
# <br>
#
# ## **Content**<br>
# The following Airbnb activity is included in this Dublin dataset:
# *   Listings, including full descriptions and average review score
# *   Reviews, including unique id for each reviewer and detailed comments
# *   Calendar, including listing id and the price and availability for that day
#
# ## **Questions**<br>
# *   What make a place to be highly-rated and what make a place to have low marks? => TF-IDF, factors correlations, sentiment analysis
# *   What factors influence demand ?
# *   The busiest time to visit Dublin according to room booking ? => time series, prediction

# %% [markdown]
# ## Data reading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd

# %%
## Yujian's loading
# calendar = pd.read_csv("/content/drive/My Drive/CA683 Data Mining/Continus Assignment/data/calendar.csv")
# listings = pd.read_csv("/content/drive/My Drive/CA683 Data Mining/Continus Assignment/data/listings.csv")
# reviews = pd.read_csv("/content/drive/My Drive/CA683 Data Mining/Continus Assignment/data/reviews.csv")
## listings_summary = pd.read_csv("/content/drive/My Drive/CA683 Data Mining/Continus Assignment/data/listings_summary.csv")
## reviews_summary = pd.read_csv("/content/drive/My Drive/CA683 Data Mining/Continus Assignment/data/reviews_summary.csv")

## Shoun's loading
calendar = pd.read_csv("/content/drive/My Drive/DCU Semester 2/Continuous Assignment/InsideAirbnb/data/calendar.csv")
listings = pd.read_csv("/content/drive/My Drive/DCU Semester 2/Continuous Assignment/InsideAirbnb/data/listings.csv")
reviews = pd.read_csv("/content/drive/My Drive/DCU Semester 2/Continuous Assignment/InsideAirbnb/data/reviews.csv")
# listings_summary = pd.read_csv("/content/drive/My Drive/DCU Semester 2/Continuous Assignment/InsideAirbnb/data/listings_summary.csv")
# reviews_summary = pd.read_csv("/content/drive/My Drive/DCU Semester 2/Continuous Assignment/InsideAirbnb/data/reviews_summary.csv")

## Aria's loading
#calendar = pd.read_csv("/content/drive/My Drive/Continuous Assessment/calendar.csv")
#listings = pd.read_csv("/content/drive/My Drive/Continuous Assessment/listings.csv")
#reviews = pd.read_csv("/content/drive/My Drive/Continuous Assessment/reviews.csv")
# listings_summary = pd.read_csv("/content/drive/My Drive/DCU Semester 2/Continuous Assignment/InsideAirbnb/data/listings_summary.csv")
# reviews_summary = pd.read_csv("/content/drive/My Drive/DCU Semester 2/Continuous Assignment/InsideAirbnb/data/reviews_summary.csv")

## Suki's loading
# calendar = pd.read_csv("/content/drive/My Drive/DCU/CA683 Data/calendar.csv")
# listings = pd.read_csv("/content/drive/My Drive/DCU/CA683 Data/listings.csv")
# reviews = pd.read_csv("/content/drive/My Drive/DCU/CA683 Data/reviews.csv")
# listings_summary = pd.read_csv("/content/drive/My Drive/DCU/CA683 Data/listings_summary.csv")
# reviews_summary = pd.read_csv("/content/drive/My Drive/DCU/CA683 Data/reviews_summary.csv")
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (61,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(calendar.shape)
calendar.head(3)
# Out:
# (3444505, 7)
#    listing_id        date  ... minimum_nights maximum_nights
# 0       44077  2019-11-26  ...              3             60
# 1      928970  2019-11-26  ...              2             28
# 2      928970  2019-11-27  ...              2             28
#
# [3 rows x 7 columns]

# %%
print(listings.shape)
listings.head(3)
# Out:
# (9437, 106)
#       id  ... reviews_per_month
# 0  44077  ...              2.07
# 1  85148  ...              0.15
# 2  85156  ...              1.64
#
# [3 rows x 106 columns]

# %%
print(reviews.shape)
reviews.head(3)
# Out:
# (359271, 6)
#    listing_id  ...                                           comments
# 0       44077  ...  We enjoyed our stay very much. The room was co...
# 1       44077  ...  We have been here 4 nights. Stay in a home is ...
# 2       44077  ...  Teresa and Hughie were great hosts. They were ...
#
# [3 rows x 6 columns]

# %%
print(listings_summary.shape)
listings_summary.head(3)
# Out:
# (9437, 16)
#       id  ... availability_365
# 0  44077  ...              240
# 1  85148  ...               24
# 2  85156  ...              223
#
# [3 rows x 16 columns]

# %%
from nltk im
